# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
links = pd.read_csv(r"D:\Datasets\Netfiz hackathon\links.csv")

# %%
movies = pd.read_csv(r"D:\Datasets\Netfiz hackathon\movies.csv")

# %%
ratings = pd.read_csv(r"D:\Datasets\Netfiz hackathon\ratings.csv")

# %%
tags = pd.read_csv(r"D:\Datasets\Netfiz hackathon\tags.csv")

# %%
merged1 = pd.merge()

# %% [markdown]
# ## Q1. What is the shape of "movies.csv"?

# %%
movies.shape
# Out:
# (9742, 3)

# %% [markdown]
# ## Q2. What is the shape of "ratings.csv"?

# %%
ratings.shape
# Out:
# (100836, 4)

# %% [markdown]
# ## Q3. How many unique "userId" are available in "ratings.csv"

# %%
ratings['userId'].nunique()
# Out:
# 610

# %% [markdown]
# ## Q4. Which movie has recieved maximum number of user ratings?

# %%
df1 = pd.merge(movies,ratings, how='inner', on='movieId')

# %%
df1.groupby(['title'])[['rating']].count().sort_values(by= 'rating', ascending=False)
# Out:
#                                            rating
# title
# Forrest Gump (1994)                           329
# Shawshank Redemption, The (1994)              317
# Pulp Fiction (1994)                           307
# Silence of the Lambs, The (1991)              279
# Matrix, The (1999)                            278
# ...                                           ...
# King Solomon's Mines (1950)                     1
# King Solomon's Mines (1937)                     1
# King Ralph (1991)                               1
# King Kong Lives (1986)                          1
# À nous la liberté (Freedom for Us) (1931)       1
#
# [9719 rows x 1 columns]

# %% [markdown]
# ## Q5. Select all the correct tags submitted by users to "Matrix, The (1999)" movie?

# %%
df2 = pd.merge(movies,tags, how='inner', on= 'movieId')
df2
# Out:
#       movieId                           title  \
# 0           1                Toy Story (1995)
# 1           1                Toy Story (1995)
# 2           1                Toy Story (1995)
# 3           2                  Jumanji (1995)
# 4           2                  Jumanji (1995)
# ...       ...                             ...
# 3678   187595  Solo: A Star Wars Story (2018)
# 3679   193565       Gintama: The Movie (2010)
# 3680   193565       Gintama: The Movie (2010)
# 3681   193565       Gintama: The Movie (2010)
# 3682   193565       Gintama: The Movie (2010)
#
#                                            genres  userId               tag  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     336             pixar
# 1     Adventure|Animation|Children|Comedy|Fantasy     474             pixar
# 2     Adventure|Animation|Children|Comedy|Fantasy     567               fun
# 3                      Adventure|Children|Fantasy      62           fantasy
# ...

# %%
matrix = df2[df2['title'].isin(['Matrix, The (1999)'])]

# %%
matrix['tag'].unique()
# Out:
# array(['martial arts', 'sci-fi', 'alternate universe', 'philosophy',
#        'post apocalyptic'], dtype=object)

# %% [markdown]
# ## Q6. What is the average user rating for movie named "Terminator 2: Judgment Day (1991)"?

# %%
terminator = df1[df1['title'].isin(['Terminator 2: Judgment Day (1991)'])]
terminator['rating'].mean()
# Out:
# 3.970982142857143

# %% [markdown]
# ## Q7 How does the data distribution of user ratings for "Fight Club (1999)" movie looks like?

# %%
flight = df1[df1['title'].isin(['Fight Club (1999)'])]

# %% [raw]
# sns.displot(flight['rating'], kind = 'kde')
# plt.axvline(flight['rating'].mean(), color='r')
# plt.axvline(flight['rating'].median(), color='g')

# %% [markdown]
# ## Q8 Which movie is the most popular based on  average user ratings?

# %%
groupby_rating = df1.groupby('movieId').agg({'rating': ['count', 'mean']}).reset_index()
groupby_rating.columns = ['movieId', 'rating_count', 'rating_mean']
data = pd.merge(movies, groupby_rating, on='movieId', how='inner')
filter_data = data[data['rating_count'] > 50]
filter_data[['title','rating_mean']].sort_values(by = 'rating_mean',ascending = False)
# Out:
#                                                   title  rating_mean
# 277                    Shawshank Redemption, The (1994)     4.429022
# 659                               Godfather, The (1972)     4.289062
# 2224                                  Fight Club (1999)     4.272936
# 974                               Cool Hand Luke (1967)     4.271930
# 602   Dr. Strangelove or: How I Learned to Stop Worr...     4.268041
# ...                                                 ...          ...
# 144                              Johnny Mnemonic (1995)     2.679245
# 145                                  Judge Dredd (1995)     2.669355
# 376   City Slickers II: The Legend of Curly's Gold (...     2.645455
# 379                                    Coneheads (1993)     2.420635
# 2028                              Wild Wild West (1999)     2.207547
#
# [436 rows x 2 columns]

# %% [markdown]
# ## Q9 Select all the correct options which comes under top 5 popular movies based on number of user ratings.

# %%
filter_data[['title','rating_count']].sort_values(by = 'rating_count',ascending = False)
# Out:
#                                  title  rating_count
# 314                Forrest Gump (1994)           329
# 277   Shawshank Redemption, The (1994)           317
# 257                Pulp Fiction (1994)           307
# 510   Silence of the Lambs, The (1991)           279
# 1938                Matrix, The (1999)           278
# ...                                ...           ...
# 3147                       Blow (2001)            51
# 3490               Training Day (2001)            51
# 3539           Mulholland Drive (2001)            51
# 118                    Bad Boys (1995)            51
# 1235       The Devil's Advocate (1997)            51
#
# [436 rows x 2 columns]

# %% [markdown]
# ## Q10 Which Sci-Fi movie is "third most popular" based on the number of user ratings?

# %%
scifi_movies = filter_data[filter_data['genres'].str.contains('Sci-Fi', case=False)]

sorted_scifi_movies = scifi_movies.sort_values(by='rating_count', ascending=False)

third_most_popular_scifi = sorted_scifi_movies.iloc[2]['title']

third_most_popular_scifi
# Out:
# 'Jurassic Park (1993)'

# %%
filter_data
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 1           2                    Jumanji (1995)
# 2           3           Grumpier Old Men (1995)
# 5           6                       Heat (1995)
# 6           7                    Sabrina (1995)
# ...       ...                               ...
# 8287   106782   Wolf of Wall Street, The (2013)
# 8354   109374  Grand Budapest Hotel, The (2014)
# 8358   109487               Interstellar (2014)
# 8457   112852    Guardians of the Galaxy (2014)
# 8673   122904                   Deadpool (2016)
#
#                                            genres  rating_count  rating_mean
# 0     Adventure|Animation|Children|Comedy|Fantasy           215     3.920930
# 1                      Adventure|Children|Fantasy           110     3.431818
# 2                                  Comedy|Romance            52     3.259615
# 5                           Action|Crime|Thriller           102     3.946078
# ...

# %%
final_df= pd.merge(filter_data,links, how='inner', on= 'movieId')
final_df
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  rating_count  rating_mean  \
# 0    Adventure|Animation|Children|Comedy|Fantasy           215     3.920930
# 1                     Adventure|Children|Fantasy           110     3.431818
# 2                                 Comedy|Romance            52     3.259615
# 3                          Action|Crime|Thriller           102     3.946078
# ...

# %% [markdown]
# ## WebScrapping

# %%
import requests
import numpy as np
from bs4 import BeautifulSoup

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    request_header = {'Content-Type': 'text/html; charset=UTF-8', 
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
                      'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.get(URL, headers=request_header)
    soup = BeautifulSoup(response.text, 'html.parser')
    imdb_rating = soup.find('span', attrs={'class' : "sc-bde20123-1 cMEQkK"})
    return imdb_rating.text if imdb_rating else np.nan

# %%
r = []
for i in final_df['imdbId']:
    r.append(scrapper(i))

# %%
rat = pd.DataFrame({'rating':r})

# %%
final_df = pd.concat([final_df,rat], axis=1)

# %%
final_df
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  rating_count  rating_mean  \
# 0    Adventure|Animation|Children|Comedy|Fantasy           215     3.920930
# 1                     Adventure|Children|Fantasy           110     3.431818
# 2                                 Comedy|Romance            52     3.259615
# 3                          Action|Crime|Thriller           102     3.946078
# ...

# %% [markdown]
# ## Q11 Mention the movieId of the movie which has the highest IMDB rating.

# %%
final_df['rating']= final_df['rating'].astype(float)

# %%
final_df.loc[final_df['rating']==final_df['rating'].max()]
# Out:
#     movieId                             title       genres  rating_count  \
# 53      318  Shawshank Redemption, The (1994)  Crime|Drama           317
#
#     rating_mean  imdbId  tmdbId  rating
# 53     4.429022  111161   278.0     9.3

# %% [markdown]
# ## Q12 Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating.

# %%
scifi_movies = final_df[final_df['genres'].str.contains('Sci-Fi', case=False)]

# %%
scifi_movies.loc[scifi_movies['rating']== scifi_movies['rating'].max()]
# Out:
#      movieId             title  \
# 424    79132  Inception (2010)
#
#                                               genres  rating_count  \
# 424  Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX           143
#
#      rating_mean   imdbId   tmdbId  rating
# 424     4.066434  1375666  27205.0     8.8
